# %% [markdown]
# <a href="https://colab.research.google.com/github/Osammysato/SERS-E-AnaliseDeDados/blob/main/FINAL_AULA_02_AN%C3%81LISE_DADOS_ENERGIA_1CCPO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **IMPORTAÇÃO DE BIBLIOTECAS**

# %%
import pandas as pd

# %% [markdown]
# # **CRIAÇÃO DO PANDAS DATA FRAME**

# %%
dados = pd.read_csv('/content/SAMPLE_ENERGY_DATA.csv')

# %%
type(dados)

# %% [markdown]
# # **ANÁLISE EXPLORATÓRIA**

# %%
# Visualizar os primeiros registros
dados.head()
# Out:
#                   Date                 Time  Global_active_power  \
# 0  2008-12-01 00:00:00  2026-08-07 09:44:00                1.502
# 1  2006-12-17 00:00:00  2026-08-07 23:39:00                0.374
# 2  2009-06-03 00:00:00  2026-08-07 17:01:00                0.620
# 3  2007-05-09 00:00:00  2026-08-07 05:53:00                0.280
# 4  2008-12-14 00:00:00  2026-08-07 02:57:00                1.372
#
#    Global_reactive_power  Voltage  Global_intensity  Sub_metering_1  \
# 0                  0.074   240.17               6.4               0
# 1                  0.264   245.50               1.8               0
# 2                  0.300   239.85               3.0               0
# 3                  0.200   235.72               1.4               0
# 4                  0.054   243.95               5.6               0
#
#    Sub_metering_2  Sub_metering_3
# 0               0              18
# 1               2               0
# 2               1               1
# ...

# %%
dados.columns
# Out:
# Index(['Date', 'Time', 'Global_active_power', 'Global_reactive_power',
#        'Voltage', 'Global_intensity', 'Sub_metering_1', 'Sub_metering_2',
#        'Sub_metering_3'],
#       dtype='object')

# %%
# Dimensões do Data Frame
dados.shape
# Out:
# 9

# %%
print(f'O total de registros é {dados.shape[0]}')
# Out:
# O total de registros é 163943

# %%
# Verificar as informações do formato dos dados de cada atributo (coluna)
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 163943 entries, 0 to 163942
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   Date                   163943 non-null  object
#  1   Time                   163943 non-null  object
#  2   Global_active_power    163943 non-null  float64
#  3   Global_reactive_power  163943 non-null  float64
#  4   Voltage                163943 non-null  float64
#  5   Global_intensity       163943 non-null  float64
#  6   Sub_metering_1         163943 non-null  int64
#  7   Sub_metering_2         163943 non-null  int64
#  8   Sub_metering_3         163943 non-null  int64
# dtypes: float64(4), int64(3), object(2)
# memory usage: 11.3+ MB

# %%
# Estatísticas descritivas dos atributos numéricos
# contagem, min, max, media, mediana, desvio padrão, distribuição dos quartis
dados.describe()
# Out:
#        Global_active_power  Global_reactive_power        Voltage  \
# count        163943.000000          163943.000000  163943.000000
# mean              1.093051               0.124073     240.827630
# std               1.062535               0.112305       3.242136
# min               0.076000               0.000000     224.870000
# 25%               0.308000               0.048000     238.980000
# 50%               0.600000               0.100000     241.000000
# 75%               1.526000               0.196000     242.880000
# max              10.290000               1.078000     253.750000
#
#        Global_intensity  Sub_metering_1  Sub_metering_2  Sub_metering_3
# count     163943.000000   163943.000000   163943.000000   163943.000000
# mean           4.633563        1.134236        1.315286        6.480124
# std            4.465014        6.202420        5.891517        8.454072
# min            0.200000        0.000000        0.000000        0.000000
# ...

# %%
dict1 = {'chave1': 'valor1', 'chave2': 'valor2', 'chave3': 'valor3'}

# %%
dados.columns
# Out:
# Index(['Date', 'Time', 'Global_active_power', 'Global_reactive_power',
#        'Voltage', 'Global_intensity', 'Sub_metering_1', 'Sub_metering_2',
#        'Sub_metering_3'],
#       dtype='object')

# %%
# Renomear os rótulos das colunas
# rename
# Parâmetro: dicionário Python que possui:
# chaves -----> rótulos atuais
# valores -----> rótulos desejados
# axis ---> 1 (colunas)
#      ---> 0 (linhas)
dados = dados.rename({'Date': 'Data',
                      'Time': 'Hora',
                      'Global_active_power': 'Potencia_Ativa',
                      'Global_reactive_power': 'Potencia_Reativa',
                      'Voltage': 'Tensao',
                      'Global_intensity': 'Corrente',
                      'Sub_metering_1': 'Consumo_1',
                      'Sub_metering_2': 'Consumo_2',
                      'Sub_metering_3': 'Consumo_3'}, axis=1)

# %%
dados.columns
# Out:
# Index(['Data', 'Hora', 'Potencia_Ativa', 'Potencia_Reativa', 'Tensao',
#        'Corrente', 'Consumo_1', 'Consumo_2', 'Consumo_3'],
#       dtype='object')

# %%
# Criar um dataframe 'df1' a partir de 'dados' sem as colunas Data e Hora
# df1 = dados.drop(['Data', 'Hora'], axis=1)
df1 = dados.drop(columns=['Data', 'Hora'])
df1.head()
# Out:
#    Potencia_Ativa  Potencia_Reativa  Tensao  Corrente  Consumo_1  Consumo_2  \
# 0           1.502             0.074  240.17       6.4          0          0
# 1           0.374             0.264  245.50       1.8          0          2
# 2           0.620             0.300  239.85       3.0          0          1
# 3           0.280             0.200  235.72       1.4          0          0
# 4           1.372             0.054  243.95       5.6          0          0
#
#    Consumo_3
# 0         18
# 1          0
# 2          1
# 3          0
# 4         18

# %%
dados.columns
# Out:
# Index(['Data', 'Hora', 'Potencia_Ativa', 'Potencia_Reativa', 'Tensao',
#        'Corrente', 'Consumo_1', 'Consumo_2', 'Consumo_3'],
#       dtype='object')

# %%
# Array a partir de uma coluna
# Exemplo: coluna Corrente
# Pandas Series
corrente = dados['Corrente']
corrente

# %%
type(corrente)

# %%
# Criar um dataframe 'df2' a partir de 'dados' somente com as colunas Tensao, Corrente,
# Consumo_2, Potencia_Reativa
# Pandas DataFrame
df2 = dados[['Tensao', 'Corrente', 'Consumo_2', 'Potencia_Reativa']]
df2.head()
# Out:
#    Tensao  Corrente  Consumo_2  Potencia_Reativa
# 0  240.17       6.4          0             0.074
# 1  245.50       1.8          2             0.264
# 2  239.85       3.0          1             0.300
# 3  235.72       1.4          0             0.200
# 4  243.95       5.6          0             0.054

# %%
dados.columns
# Out:
# Index(['Data', 'Hora', 'Potencia_Ativa', 'Potencia_Reativa', 'Tensao',
#        'Corrente', 'Consumo_1', 'Consumo_2', 'Consumo_3'],
#       dtype='object')

# %%
# Criar um dataframe 'df3' a partir de 'dados' somente com as primeiras 4 colunas
# Métodos iloc e loc
# iloc ---> acesso por índice
# loc ---> acesso por rótulos
# Exemplo: .iloc[linhas, colunas]
# : -----> seleciona todos os registros (linhas)
# 0:4 ----> seleciona da coluna 0 até a coluna anterior à 4
df3 = dados.iloc[:, 0:4]
df3.head()
# Out:
#                   Data                 Hora  Potencia_Ativa  Potencia_Reativa
# 0  2008-12-01 00:00:00  2026-08-07 09:44:00           1.502             0.074
# 1  2006-12-17 00:00:00  2026-08-07 23:39:00           0.374             0.264
# 2  2009-06-03 00:00:00  2026-08-07 17:01:00           0.620             0.300
# 3  2007-05-09 00:00:00  2026-08-07 05:53:00           0.280             0.200
# 4  2008-12-14 00:00:00  2026-08-07 02:57:00           1.372             0.054

# %%
dados.shape[0]
# Out:
# 163943

# %%
# Qual é o valor máximo de demanda energética (Potencia_Ativa)? (PMAX)
PMAX = dados['Potencia_Ativa'].max()
print(f'O valor máximo de demanda energética é: {PMAX:.2f} kW')
# Out:
# O valor máximo de demanda energética é: 10.29 kW

# %%
# Qual é o limiar de 60% da demanda máxima? (P60)
P60 = 0.6 * PMAX
print(f'O limiar de 60% da demanda máxima é: {P60:.2f} kW')
# Out:
# O limiar de 60% da demanda máxima é: 6.17 kW

# %%
# Criar um dataframe 'df4' a partir de dados somente com Data, Hora,
# Corrente e Potencia_Ativa
df4 = dados[['Data', 'Hora', 'Corrente', 'Potencia_Ativa']]
df4.head()
# Out:
#                   Data                 Hora  Corrente  Potencia_Ativa
# 0  2008-12-01 00:00:00  2026-08-07 09:44:00       6.4           1.502
# 1  2006-12-17 00:00:00  2026-08-07 23:39:00       1.8           0.374
# 2  2009-06-03 00:00:00  2026-08-07 17:01:00       3.0           0.620
# 3  2007-05-09 00:00:00  2026-08-07 05:53:00       1.4           0.280
# 4  2008-12-14 00:00:00  2026-08-07 02:57:00       5.6           1.372

# %%
df4.shape[0]
# Out:
# 163943

# %%
# Criar um dataframe 'df5' a partir de 'df4' somente com registros de consumidores
# que ultrapassaram o limiar P60.

# %%
P60
# Out:
# 6.1739999999999995

# %%
df5 = df4[df4['Potencia_Ativa'] > P60]
df5.head()
# Out:
#                      Data                 Hora  Corrente  Potencia_Ativa
# 296   2007-01-20 00:00:00  2026-08-07 19:19:00      27.2           6.240
# 581   2007-10-13 00:00:00  2026-08-07 20:12:00      30.2           6.888
# 1488  2008-07-12 00:00:00  2026-08-07 15:44:00      27.2           6.398
# 2453  2009-12-24 00:00:00  2026-08-07 23:00:00      26.6           6.406
# 2995  2008-09-04 00:00:00  2026-08-07 20:12:00      30.0           6.838

# %%
372 / 160000
# Out:
# 0.002325

# %%
# Quantos consumidores estão acima de P60?
print(f'Existem {df5.shape[0]} de consumidores acima de P60')
# Out:
# Existem 372 de consumidores acima de P60

# %% [markdown]
# GERE UM HISTOGRAMA APENAS DA COLUNA Potencia_Ativa e me envie um relatório do motivo de existirem somente 372 de 160K consumindo acima de P60.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 6))
sns.histplot(dados['Potencia_Ativa'], kde=True, bins=50)
plt.axvline(x=P60, color='r', linestyle='--', label=f'Threshold (P60 = {P60:.2f} kW)')
plt.title('Distribution of Potencia_Ativa')
plt.xlabel('Potencia_Ativa (kW)')
plt.ylabel('Frequency')
plt.legend()
plt.show()

# %% [markdown]
# ### Análise do Limiar P60 e Consumo de Energia
#
# O histograma da coluna 'Potencia_Ativa' (Potência Ativa) mostra a distribuição do consumo de energia no seu dataset. Podemos observar que a maioria dos registros de consumo de energia se concentra em valores baixos.
#
# O P60 foi calculado como 60% da demanda máxima (`PMAX`), resultando em um valor de **6.17 kW**. A linha vertical vermelha no histograma indica este limiar. É evidente que uma porção muito pequena da distribuição de 'Potencia_Ativa' ultrapassa este valor.
#
# Existem algumas razões prováveis para o fato de apenas 372 dos 163.943 registros de consumo estarem acima do limiar P60 (aproximadamente 0.23% do total):
#
# 1.  **Natureza dos Dados (Carga Base vs. Carga de Pico):** A maioria dos consumidores, ou a maior parte do tempo de consumo, opera em níveis de potência abaixo da capacidade máxima. Atingir 60% da potência máxima global (que é `PMAX`) é um evento relativamente raro, geralmente associado a picos de consumo ou a cargas de equipamentos específicos e de alta demanda.
# 2.  **Eficiência Energética:** Pode indicar que os equipamentos ou hábitos de consumo da maioria dos usuários são eficientes e não exigem constantemente altos níveis de potência.
# 3.  **Dimensionamento da Capacidade:** A capacidade máxima de 10.29 kW (`PMAX`) pode ser dimensionada para acomodar situações de carga muito elevadas, que não ocorrem com frequência na operação diária ou em todos os pontos de medição.
# 4.  **Amostragem ou Período de Tempo:** Se os dados representam um período específico ou são uma amostra, pode ser que os eventos de alto consumo sejam raros nesse período ou não tenham sido capturados em maior frequência.
# 5.  **Outliers:** Os valores que excedem o P60 podem ser considerados picos de demanda ou até mesmo *outliers* em relação ao comportamento de consumo médio, indicando momentos de uso intensivo de energia.
#
# Em resumo, a pequena quantidade de registros acima de P60 sugere que a operação normal e a maioria dos padrões de consumo no dataset estão bem abaixo dos picos de demanda mais elevados.
