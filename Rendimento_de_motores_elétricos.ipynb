# %% [markdown]
# <a href="https://colab.research.google.com/github/sammymourasato-hub/Exercicios-tritiack/blob/main/Rendimento_de_motores_el%C3%A9tricos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Arquivo .py ----> Python
# Arquivo de .ipynb ----> Jupyter Notebook
# IDE ----> Ambiente de desenvolvimento integrado --------> maquina local (vscode, Cursor, Pycharm)

# %% [markdown]
# # **Exemplo - MOTOR DE INDUÇÃO TRIFÁSICO**

# %% [markdown]
# 1. INSERÇÃO DOS DADOS DE PLACA PELO USUARIO

# %%
# Potência Últil (Mecânica) ---> em Watts
PU = int(input("insira a potência últil, em KW:"))
# Rendimento ---> n = PU / P
n = (float(input("insira o fator de rendimento percentual: ")))/100
# Fator de potência ----> fp = P / S
fp = float(input("insira o fator de potência (de 0 a 1) "))
# Out:
# insira a potência últil, em KW:3
# insira o fator de rendimento percentual: 76
# insira o fator de potência (de 0 a 1) 0.80

# %% [markdown]
# 2. CÁLCULO DAS PONTÊNCIAS ATIVA (P), APARENTE (S) E REATIVA (Q)

# %%
#n = PU / P
# potência Ativa (P)
P = PU / n
#Potência Aparente (S)
#fp = P / S
S = P / fp
# Potência Reativa (Q)
Q = (S**2 - P**2)**0.5

# %% [markdown]
# 3. Apresentação dos resultados

# %%
# f-string
#Limitsr od resultados a 3 casas decimais
print(f"A potência ativa será de {P:.3f} KW")
print(f"A potência aparente será de {S:.3f} KVA")
print(f"A potência reativa será de {Q:.3f} KVAr")
# Out:
# A potência ativa será de 3.947 KW
# A potência aparente será de 4.934 KVA
# A potência reativa será de 2.961 KVAr

# %% [markdown]
# EXERCÍCIOS

# %% [markdown]
# ### ANÁLISE DO MOTOR 1

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 1. INSERÇÃO DE DADOS DE PLACA PELO USUARIO

# %%
# Potência Últil (Mecânica) ---> em Watts
PU = float(input("insira a potência últil, em KW:"))
# Rendimento ---> n = PU / P
n = (float(input("insira o fator de rendimento percentual: ")))/100
# Fator de potência ----> fp = P / S
fp = float(input("insira o fator de potência (de 0 a 1) "))
# Out:
# insira a potência últil, em KW:0.75
# insira o fator de rendimento percentual: 83
# insira o fator de potência (de 0 a 1) 0.82

# %% [markdown]
# 2. CÁLCULO DAS PONTÊNCIAS ATIVA (P), APARENTE (S) E REATIVA (Q)

# %%
#n = PU / P
# potência Ativa (P)
P = PU / n
#Potência Aparente (S)
#fp = P / S
S = P / fp
# Potência Reativa (Q)
Q = (S**2 - P**2)**0.5

# %% [markdown]
# 3. Apresentação dos resultados

# %%
# f-string
#Limitsr od resultados a 3 casas decimais
# ".3F" --> DIFINIR QUANTAS CASAS DECIMAIS IRÁ APARECER
print(f"A potência ativa será de {P:.3f} KW")
print(f"A potência aparente será de {S:.3f} KVA")
print(f"A potência reativa será de {Q:.3f} KVAr")
# Out:
# A potência ativa será de 0.904 KW
# A potência aparente será de 1.102 KVA
# A potência reativa será de 0.631 KVAr

# %% [markdown]
# ### ANÁLISE MOTOR 2

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 1. INSERÇÃO DE DADOS DE PLACA PELO USUARIO

# %%
# Potência Últil (Mecânica) ---> em Watts
PU = float(input("insira a potência últil, em KW:"))
# Rendimento ---> n = PU / P
n = (float(input("insira o fator de rendimento percentual: ")))/100
# Fator de potência ----> fp = P / S
fp = float(input("insira o fator de potência (de 0 a 1) "))
# Out:
# insira a potência últil, em KW:7.5
# insira o fator de rendimento percentual: 91
# insira o fator de potência (de 0 a 1) 0.82

# %% [markdown]
# 2. CÁLCULO DAS PONTÊNCIAS ATIVA (P), APARENTE (S) E REATIVA (Q)

# %%
#n = PU / P
# potência Ativa (P)
P = PU / n
#Potência Aparente (S)
#fp = P / S
S = P / fp
# Potência Reativa (Q)
Q = (S**2 - P**2)**0.5

# %% [markdown]
# 3. APRESENTAÇÃO DOS RESULTADOS

# %%
# f-string
#Limitsr od resultados a 3 casas decimais
# ".3F" --> DIFINIR QUANTAS CASAS DECIMAIS IRÁ APARECER
print(f"A potência ativa será de {P:.3f} KW")
print(f"A potência aparente será de {S:.3f} KVA")
print(f"A potência reativa será de {Q:.3f} KVAr")
# Out:
# A potência ativa será de 8.242 KW
# A potência aparente será de 10.051 KVA
# A potência reativa será de 5.753 KVAr

# %% [markdown]
# ### ANÁLISE MOTOR 3

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 1. INSERÇÃO DE DADOS DE PLACA PELO USUARIO

# %%
# Potência Últil (Mecânica) ---> em Watts
PU = float(input("insira a potência últil, em KW:"))
# Rendimento ---> n = PU / P
n = (float(input("insira o fator de rendimento percentual: ")))/100
# Fator de potência ----> fp = P / S
fp = float(input("insira o fator de potência (de 0 a 1) "))
# Out:
# insira a potência últil, em KW:12.6
# insira o fator de rendimento percentual: 85
# insira o fator de potência (de 0 a 1) 0.89

# %% [markdown]
# 1. CÁLCULO DAS PONTÊNCIAS ATIVA (P), APARENTE (S) E REATIVA (Q)

# %%
#n = PU / P
# potência Ativa (P)
P = PU / n
#Potência Aparente (S)
#fp = P / S
S = P / fp
# Potência Reativa (Q)
Q = (S**2 - P**2)**0.5

# %% [markdown]
# 3. APRESENTAÇÃO DOS RESULTADOS

# %%
# f-string
#Limitsr od resultados a 3 casas decimais
# ".3F" --> DIFINIR QUANTAS CASAS DECIMAIS IRÁ APARECER
print(f"A potência ativa será de {P:.3f} KW")
print(f"A potência aparente será de {S:.3f} KVA")
print(f"A potência reativa será de {Q:.3f} KVAr")
# Out:
# A potência ativa será de 14.824 KW
# A potência aparente será de 16.656 KVA
# A potência reativa será de 7.594 KVAr

# %% [markdown]
# ### ANÁLISE DO MOTOR 4

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
PU = float(input("insira a potência últil, em KW:"))
n = (float(input("insira o fator de rendimento percentual: ")))/100
fp = float(input("insira o fator de potência (de 0 a 1) "))

#Calculo

P = PU / n
S = P / fp
Q = (S**2 - P**2)**0.5

#APRESENTAÇÃO DOS RESULTADOS

print(f"A potência ativa será de {P:.3f} KW")
print(f"A potência aparente será de {S:.3f} KVA")
print(f"A potência reativa será de {Q:.3f} KVAr")
# Out:
# insira a potência últil, em KW:300
# insira o fator de rendimento percentual: 95.8
# insira o fator de potência (de 0 a 1) 0.89
# A potência ativa será de 313.152 KW
# A potência aparente será de 351.857 KVA
# A potência reativa será de 160.433 KVAr
